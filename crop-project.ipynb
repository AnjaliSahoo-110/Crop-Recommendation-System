# %%
import os
print(os.listdir())
# Out:
# ['.anaconda', '.conda', '.continuum', '.docker', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.node_repl_history', '.python_history', '.vscode', '.vscode-shared', 'anaconda_projects', 'AppData', 'Application Data', 'CNS.ipynb', 'Contacts', 'Cookies', 'crop-project.ipynb', 'Demo.ipynb', 'Demo2.ipynb', 'Documents', 'Downloads', 'Favorites', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{58c42e7d-edb3-11ef-b695-000010027d6e}.TM.blf', 'NTUSER.DAT{58c42e7d-edb3-11ef-b695-000010027d6e}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{58c42e7d-edb3-11ef-b695-000010027d6e}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Videos']

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\LENOVO

# %%
print(os.listdir())
# Out:
# ['.anaconda', '.conda', '.continuum', '.docker', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.node_repl_history', '.python_history', '.vscode', '.vscode-shared', 'anaconda_projects', 'AppData', 'Application Data', 'CNS.ipynb', 'Contacts', 'Cookies', 'crop-project.ipynb', 'Demo.ipynb', 'Demo2.ipynb', 'Documents', 'Downloads', 'Favorites', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{58c42e7d-edb3-11ef-b695-000010027d6e}.TM.blf', 'NTUSER.DAT{58c42e7d-edb3-11ef-b695-000010027d6e}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{58c42e7d-edb3-11ef-b695-000010027d6e}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Videos']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\LENOVO

# %%
import os
print(os.listdir())
# Out:
# ['.anaconda', '.conda', '.continuum', '.docker', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.node_repl_history', '.python_history', '.vscode', '.vscode-shared', 'anaconda_projects', 'AppData', 'Application Data', 'CNS.ipynb', 'Contacts', 'Cookies', 'crop-project.ipynb', 'Demo.ipynb', 'Demo2.ipynb', 'Documents', 'Downloads', 'Favorites', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{58c42e7d-edb3-11ef-b695-000010027d6e}.TM.blf', 'NTUSER.DAT{58c42e7d-edb3-11ef-b695-000010027d6e}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{58c42e7d-edb3-11ef-b695-000010027d6e}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Videos']

# %%
import os

print(os.listdir("OneDrive"))
# Out:
# ['.849C9593-D756-4E56-8D6E-42412F2A707B', 'Attachments', 'Desktop', 'desktop.ini', 'Documents', 'Getting started with OneDrive.pdf', 'Personal Vault.lnk', 'Pictures']

# %%
import os

print(os.listdir("OneDrive/Documents"))
# Out:
# ['abhinab resume (1).docx', 'abhinab resume.1.docx', 'Amit final node js (1) new.docx', 'Anjali node minor project (1).docx', 'AnjaliSahoo-Resume (1).docx', 'AnjaliSahoo-Resume (2) final.pdf', 'AnjaliSahoo-Resume (2).docx', 'AnjaliSahoo-Resume.docx', 'Crop-Recommendation-System', 'Custom Office Templates', 'Dedicated bakery worker with hands.docx', 'desktop.ini', 'GRP 12.docx', 'GRP-05 Node.js.pdf', 'IDB Project Report.docx', 'IDT Project Report ANJALI.pdf', 'IDT Project Report SURBHAV(1).pdf', 'IDT Project Report SURBHAV.pdf', 'ITD Project Report ABHINAB.pdf', 'ITD Project Report anjali 2.pdf', 'MIDSEM ITC 2024.txt', 'NODE PROJECT ANSHU(1).pdf', 'nodejs mini proj aalka pdf.pdf', 'nodejs mini proj aalka pdf1.pdf', 'nodejs mini proj aalka.docx', 'Node_js_Q11 anshu.docx', 'Presentation1.pptx', 'Print Aadi-12.docx', 'Resume code.docx', 'RESUME.pdf', 'WindowsPowerShell']

# %%
import pandas as pd

df = pd.read_csv(
    r"OneDrive/Documents/Crop-Recommendation-System/Crop_recommendation.csv"
)

df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
# Import Libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Load Dataset
df = pd.read_csv(
    r"OneDrive/Documents/Crop-Recommendation-System/Crop_recommendation.csv"
)

# Display Basic Information
print("Dataset Shape:")
print(df.shape)

print("\nFirst 5 Rows:")
print(df.head())

print("\nCrop Classes:")
print(df['label'].unique())

# Features and Target
X = df.drop('label', axis=1)
y = df['label']

# Encode Labels
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)

# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y_encoded,
    test_size=0.2,
    random_state=42
)

# Random Forest Model
model = RandomForestClassifier(
    n_estimators=300,
    random_state=42
)

# Train Model
model.fit(X_train, y_train)

# Predictions
predictions = model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, predictions)

print("\n==============================")
print("MODEL RESULTS")
print("==============================")
print(f"Accuracy: {accuracy*100:.2f}%")

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, predictions))

# Example Prediction
sample = sample = pd.DataFrame({
    'N':[90],
    'P':[42],
    'K':[43],
    'temperature':[20.87],
    'humidity':[82.00],
    'ph':[6.50],
    'rainfall':[202.93]
})

prediction = model.predict(sample)

crop_name = encoder.inverse_transform(prediction)

print("Recommended Crop:", crop_name[0])
# Out:
# Dataset Shape:
# (2200, 8)
#
# First 5 Rows:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
#
# Crop Classes:
# ['rice' 'maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans'
#  'mungbean' 'blackgram' 'lentil' 'pomegranate' 'banana' 'mango' 'grapes'
#  'watermelon' 'muskmelon' 'apple' 'orange' 'papaya' 'coconut' 'cotton'
#  'jute' 'coffee']
#
# ...
# MODEL RESULTS
# ...
# Accuracy: 99.32%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        20
# ...

# %%
import pandas as pd

df = pd.read_csv(
    r"OneDrive/Documents/Crop-Recommendation-System/Crop_recommendation.csv"
)

df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))
sns.countplot(y=df['label'])
plt.title("Crop Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=300,
    random_state=42
)

model.fit(X_train, y_train)

predictions = model.predict(X_test)

# %%
importance = model.feature_importances_

plt.figure(figsize=(10,5))
plt.bar(X.columns, importance)

plt.title("Feature Importance")
plt.xlabel("Features")
plt.ylabel("Importance")

plt.show()

# %%
import joblib

joblib.dump(model, "crop_model.pkl")
joblib.dump(encoder, "label_encoder.pkl")

print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
import os

print("Current Folder:")
print(os.getcwd())

print("\nFiles:")
print(os.listdir())
# Out:
# Current Folder:
# C:\Users\LENOVO
#
# Files:
# ...
